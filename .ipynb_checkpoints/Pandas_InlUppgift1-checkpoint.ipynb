# %% [markdown]
# Imorterar modulen pandas som "pd"

# %%
import pandas as pd

# %% [markdown]
# "Läs in ”Automobile_data.csv” i din Jupyter notebook och skriv ut de
# första och sista fem raderna från den givna datamängden."

# %% [markdown]
# -Läser in data-filen som en DataFrame

# %%
df = pd.read_csv("Automobile_data.csv")

# %% [markdown]
# -Skriver ut Dataframe, den visar dom 5 första (Head) och 5 sista (Tail)

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %% [markdown]
# "Skriv därefter ut den dyraste bilens företagsnamn och pris."

# %% [markdown]
# -Sorterar df på price (desecending) och tar första raden (head(1)) och skriver ut enbart company och price

# %%
df.sort_values(by=["price"], ascending=False).head(1)[["company", "price"]]
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# "Skriv därefter ut data om alla Toyota som ni har i lager."

# %% [markdown]
# -Använder df.loc med ett condition för att ta ut all data om company == toyota

# %%
df.loc[df["company"] == "toyota"]
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %% [markdown]
# "Räkna totalt antal bilar i lager per bilmärke och skriv ut detta."

# %% [markdown]
# -Här används value_counts() för att räkna ut hur många antal det är av varje value i kolumnen company

# %%
df["company"].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %% [markdown]
# "Skriv ut data om varje bilmärkes dyraste bil."

# %% [markdown]
# Sorterar värderna i "price" högst till lägst och visar kolumnerna company & price samt tar bort alla duplicates från company så varje märke bara visar 1 värde

# %%
df.sort_values(by="price", ascending=False)[["company", "price"]].drop_duplicates("company")
# Out:
#           company    price
# 35  mercedes-benz  45400.0
# 11            bmw  41315.0
# 46        porsche  37028.0
# 26         jaguar  36000.0
# 6            audi  18920.0
# 31          mazda  18344.0
# 2     alfa-romero  16500.0
# 54         toyota  15750.0
# 44         nissan  13499.0
# 60          volvo  13415.0
# 19          honda  12945.0
# 58     volkswagen   9995.0
# 39     mitsubishi   8189.0
# 21          isuzu   6785.0
# 15      chevrolet   6575.0
# 16          dodge   6377.0

# %% [markdown]
# "Skriv ut alla europeiska bilmärkens bilmärke."

# %% [markdown]
# Lägger till en ny kolumn som heter country som ska innehålla värdet EU och sätter alla europeiska märken till det värdet

# %%
df.insert(10, 'country', 'EU')
df['country'] = df['company'].map({'volvo':'EU','audi':'EU','bmw':'EU', 'porsche':'EU','alfa-romero':'EU','jaguar':'EU','volkswagen':'EU'})

# %% [markdown]
# Skriver ut all data där country = EU, så den skriver ut alla bilar som är europeiska

# %%
df.loc[df["country"] == "EU"]
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# 5       5         audi        sedan        99.8   177.3         ohc
# 6       6         audi        wagon       105.8   192.7         ohc
# 7       9          bmw        sedan       101.2   176.8         ohc
# 8      10          bmw        sedan       101.2   176.8         ohc
# 9      11          bmw        sedan       101.2   176.8         ohc
# 10     13          bmw        sedan       103.5   189.0         ohc
# 11     14          bmw        sedan       103.5   193.8         ohc
# 12     15          bmw        sedan       110.0   197.0         ohc
# ...
