# %%
import numpy as np
import os

# %%
CURR_DIR_PATH = os.path.dirname(os.path.realpath(__file__))
speed_measurement_path = CURR_DIR_PATH + "/speed_measurements.txt"
speed_data = np.genfromtxt(speed_measurement_path, delimiter=",", dtype="str", autostrip=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 CURR_DIR_PATH = os.path.dirname(os.path.realpath(__file__))
#       2 speed_measurement_path = CURR_DIR_PATH + "/speed_measurements.txt"
#       3 speed_data = np.genfromtxt(speed_measurement_path, delimiter=",", dtype="str", autostrip=True)
#
# NameError: name '__file__' is not defined

# %%
print(speed_measurement_path)
print(speed_data)
