# %% [markdown]
# Det här är en "markdown".

# %%
print("Det här är kod")
# Out:
# Det här är kod

# %% [markdown]
# Blablablblablablablabla

# %%
var = "Hejsanhoppsan"

counter = 0
for char in var:
    counter += 1
    
print(f"Det är {counter} bokstäver i variabeln")
# Out:
# Det är 13 bokstäver i variabeln

# %%
asd = "Hej"

# %%
print(asd)
# Out:
# Hej
