# %%
from PyPDF2 import PdfReader

reader = PdfReader("1011apdf.pdf")
number_of_pages = len(reader.pages)
page = reader.pages[0]
text = page.extract_text()

# %%
number_of_pages
# Out:
# 1

# %%
text_list = []

# %%
for e in text:
    text_list.append(e)

# %%
text_list
# Out:
# [' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'H',
#  'U',
#  'S',
#  ' ',
#  '2',
#  ' ',
#  ' ',
#  'P',
#  'L',
#  'A',
#  'N',
# ...

# %%
text
# Out:
# '                                  \n                                         \n                                    HUS 2  PLAN 7                       \n                                    \n1:100@A1          012345 m10A\nB\nC\nD\nE\nF\nG\nHa30p2070.dgna30p1070.dgnram-A1.dgna30p2070.dgna30p1070.dgna30pm000.dgnATTACHED REFERENCE FILES:A\nBYGGHANDLINGAVSÄTTNING PENTRY900 5400 5400 5400 8100 5400 5400 5400\n600 5400 5400 5400 5400 5400 5400 5400 8100EJ STATUS BH. VÄGG AV SKIVORBETONG VÄGG            PLATSGJ/ PREFAB.\nENLIGT HYRESGÄSTS ANPASSNINGFÖRBEREDS FÖR ATT UTRUSTAS FÖR WC ALT. STÄDWC/STÄD RUM 149, 150, 349, 350FÖRKLARINGAR\nFÖRESKRIFTER\nHÄNVISNINGARN\n10-06-01 CaHa\n                  \nABYGGHANDLINGAR 90APM-01\n2010-04-30BRANDGRÄNSER SE RITNING A98.1-0.0700VÄGGTYPER SE RITNING A43.6-4.0101-0103DELPLAN SE RITNING  A40.1-2.0422KRITISKA SNITT SE RITNING A40.2-2.7171SEKTION SE RITNING A40.2-1.7100ALLA MÅTT ANGES I MM\nA-40.1-0720K\nV\nEBET ANT ÄNDRINGEN AVSER DATUM SIGN\nUPPDRAG.NR 
# ...

# %%
text2 = text

# %%
print(text.count("\n"))
# Out:
# 331

# %%
text2.replace("\n", "")
# Out:
# '                                                                                                               HUS 2  PLAN 7                                                           1:100@A1          012345 m10ABCDEFGHa30p2070.dgna30p1070.dgnram-A1.dgna30p2070.dgna30p1070.dgna30pm000.dgnATTACHED REFERENCE FILES:ABYGGHANDLINGAVSÄTTNING PENTRY900 5400 5400 5400 8100 5400 5400 5400600 5400 5400 5400 5400 5400 5400 5400 8100EJ STATUS BH. VÄGG AV SKIVORBETONG VÄGG            PLATSGJ/ PREFAB.ENLIGT HYRESGÄSTS ANPASSNINGFÖRBEREDS FÖR ATT UTRUSTAS FÖR WC ALT. STÄDWC/STÄD RUM 149, 150, 349, 350FÖRKLARINGARFÖRESKRIFTERHÄNVISNINGARN10-06-01 CaHa                  ABYGGHANDLINGAR 90APM-012010-04-30BRANDGRÄNSER SE RITNING A98.1-0.0700VÄGGTYPER SE RITNING A43.6-4.0101-0103DELPLAN SE RITNING  A40.1-2.0422KRITISKA SNITT SE RITNING A40.2-2.7171SEKTION SE RITNING A40.2-1.7100ALLA MÅTT ANGES I MMA-40.1-0720KVEBET ANT ÄNDRINGEN AVSER DATUM SIGNUPPDRAG.NR RITAD/KONSTR AV HANDLÄGGAREDATUM ANSVARIGSKALA N
# ...

# %%
if " " > 1 in text2:
    text2.replace(" ", "")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 if " " > 1 in text2:
#       2     text2.replace(" ", "")
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
text2.split()
# Out:
# ['HUS',
#  '2',
#  'PLAN',
#  '7',
#  '1:100@A1',
#  '012345',
#  'm10A',
#  'B',
#  'C',
#  'D',
#  'E',
#  'F',
#  'G',
#  'Ha30p2070.dgna30p1070.dgnram-A1.dgna30p2070.dgna30p1070.dgna30pm000.dgnATTACHED',
#  'REFERENCE',
#  'FILES:A',
#  'BYGGHANDLINGAVSÄTTNING',
#  'PENTRY900',
#  '5400',
#  '5400',
#  '5400',
#  '8100',
#  '5400',
#  '5400',
#  '5400',
#  '600',
#  '5400',
#  '5400',
#  '5400',
#  '5400',
#  '5400',
#  '5400',
#  '5400',
#  '8100EJ',
#  'STATUS',
#  'BH.',
#  'VÄGG',
#  'AV',
#  'SKIVORBETONG',
#  'VÄGG',
#  'PLATSGJ/',
#  'PREFAB.',
#  'ENLIGT',
#  'HYRESGÄSTS',
#  'ANPASSNINGFÖRBEREDS',
#  'FÖR',
#  'ATT',
#  'UTRUSTAS',
#  'FÖR',
#  'WC',
#  'ALT.',
#  'STÄDWC/STÄD',
#  'RUM',
#  '149,',
#  '150,',
#  '349,',
#  '350FÖRKLARINGAR',
#  'FÖRESKRIFTER',
#  'HÄNVISNINGARN',
#  '10-06-01',
#  'CaHa',
#  'ABYGGHANDLINGAR',
#  '90APM-01',
#  '2010-04-30BRANDGRÄNSER',
#  'SE',
#  'RITNING',
#  'A98.1-0.0700VÄGGTYPER',
#  'SE',
#  'RITNING',
# ...

# %%
text.split()
# Out:
# ['HUS',
#  '2',
#  'PLAN',
#  '7',
#  '1:100@A1',
#  '012345',
#  'm10A',
#  'B',
#  'C',
#  'D',
#  'E',
#  'F',
#  'G',
#  'Ha30p2070.dgna30p1070.dgnram-A1.dgna30p2070.dgna30p1070.dgna30pm000.dgnATTACHED',
#  'REFERENCE',
#  'FILES:A',
#  'BYGGHANDLINGAVSÄTTNING',
#  'PENTRY900',
#  '5400',
#  '5400',
#  '5400',
#  '8100',
#  '5400',
#  '5400',
#  '5400',
#  '600',
#  '5400',
#  '5400',
#  '5400',
#  '5400',
#  '5400',
#  '5400',
#  '5400',
#  '8100EJ',
#  'STATUS',
#  'BH.',
#  'VÄGG',
#  'AV',
#  'SKIVORBETONG',
#  'VÄGG',
#  'PLATSGJ/',
#  'PREFAB.',
#  'ENLIGT',
#  'HYRESGÄSTS',
#  'ANPASSNINGFÖRBEREDS',
#  'FÖR',
#  'ATT',
#  'UTRUSTAS',
#  'FÖR',
#  'WC',
#  'ALT.',
#  'STÄDWC/STÄD',
#  'RUM',
#  '149,',
#  '150,',
#  '349,',
#  '350FÖRKLARINGAR',
#  'FÖRESKRIFTER',
#  'HÄNVISNINGARN',
#  '10-06-01',
#  'CaHa',
#  'ABYGGHANDLINGAR',
#  '90APM-01',
#  '2010-04-30BRANDGRÄNSER',
#  'SE',
#  'RITNING',
#  'A98.1-0.0700VÄGGTYPER',
#  'SE',
#  'RITNING',
# ...
